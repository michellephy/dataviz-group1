# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from datetime import timedelta, date
import seaborn as sns

# %%
plt.xlabel('Months', fontsize = 13)
plt.ylabel('Average temperature (Fahrenheit)', fontsize = 13)
plt.title("Average Temperature per Month", fontsize = 15)
plt.ylim([0, 100])
x = ['January', 'February', 'March']
y = ['March', 'April', 'May', 'June']
z= ['June', 'July', 'August', 'September']
d = ["November", 'December']
a= ['September', 'October', 'November'] 

jan_feb = [33.81, 35.98, 41.33]
mar_may = [41.33, 54.47, 61.69, 71.93]
jun_aug = [71.93, 79.88, 75.46, 70.61]
nov_dec = [44.13, 38.61]
sep_nov = [70.61, 60.07, 44.13]
labels = [x,y,z,d,a]

plt.plot(x, jan_feb, marker = "*", color = 'cornflowerblue')
plt.plot(y, mar_may, marker = "d", color = 'springgreen')
plt.plot(z, jun_aug, marker = "o", color= 'red')
plt.plot(a, sep_nov, marker = '^', color = 'peru')
plt.plot(d, nov_dec, marker = '*', color = 'cornflowerblue')
plt.xticks(rotation = '45')
plt.gcf().set_facecolor('white')
plt.gcf().set_size_inches(10,6)
plt.savefig('avg temp per month.png', bbox_inches="tight")

# %%
averages= [33.81, 35.98, 41.33, 54.47, 61.69, 71.93, 79.88, 75.46, 70.61, 60.07, 44.13, 38.61]
crimes= [238.64, 210.14, 233.66, 228.02, 232.25, 207.2, 232.53, 214.79, 197.84, 207.49, 184.65, 161.98]
avg = [33.81, 35.98, 41.33, 54.47, 61.69]
main = [71.93, 79.88, 75.46]
last = [70.61, 60.07, 44.13, 38.61]
avg2 = [238.64, 210.14, 233.66, 228.02,232.25]
main2 = [232.25, 207.2, 232.53,214.79]
last2 = [214.79, 197.84, 207.49, 184.65, 161.98]

avg3 = ['January', 'February', 'March', 'April', 'May']
main3 = ['May','June', 'July', 'August']
last3 = ['August','September', 'October', 'November', 'December']

# %%
xy = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
x = ['January', 'February', 'March']
y = ['March', 'April', 'May', 'June']
z= ['June', 'July', 'August', 'September']
d = ["November", 'December']
a= ['September', 'October', 'November'] 

jan_feb = [33.81, 35.98, 41.33]
jf = [238.64, 210.14, 233.6]
mar_may = [41.33, 54.47, 61.69, 71.93]
mm = [233.6,228.02, 232.25, 207.2]
jun_aug = [71.93, 79.88, 75.46, 70.61]
ja = [207.2, 232.53, 214.79, 197.84]
nov_dec = [44.13, 38.61]
nd = [184.65, 161.98]
sep_nov = [70.61, 60.07, 44.13]
sn = [197.84, 207.49, 184.65]
crimes= [238.64, 210.14, 233.66, 228.02, 232.25, 207.2, 232.53, 214.79, 197.84, 207.49, 184.65, 161.98]


fig, (ax1, ax2) = plt.subplots(2, sharex = 'all')
ax1.plot(x, jan_feb, marker = "*", color = 'cornflowerblue')
ax1.plot(y, mar_may, marker = "d", color = 'springgreen')
ax1.plot(z, jun_aug, marker = "o", color= 'red')
ax1.plot(a, sep_nov, marker = '^', color = 'peru')
ax1.plot(d, nov_dec, marker = '*', color = 'cornflowerblue')
ax2.plot(x, jf,marker = "*", color = 'cornflowerblue')
ax2.plot(y, mm, marker = "d", color = 'springgreen')
ax2.plot(z, ja, marker = "o", color= 'red')
ax2.plot(a, sn, marker = '^', color = 'peru')
ax2.plot(d, nd, marker = '*', color = 'cornflowerblue')
plt.xlabel('Months')
ax2.set_ylabel("Monthly Crime Rate \n (per 100,000)", fontsize = 9)
ax1.set_ylabel("Average Monthly Temp", fontsize = 9)
plt.xticks(rotation = '45')
ax1.set_title("Temperature per Month")
ax2.set_title("Crime Rate per Month")
ax1.set_ylim([0,100])
ax2.set_ylim([0,300])


plt.gcf().set_facecolor('white')
plt.gcf().set_size_inches(10,6)
plt.savefig('subplot.png', bbox_inches="tight")
#plt.show()

# %%
xy = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
x = ['January', 'February', 'March']
y = ['March', 'April', 'May', 'June']
z= ['June', 'July', 'August', 'September']
d = ["November", 'December']
a= ['September', 'October', 'November'] 

jf = [238.64, 210.14, 233.6]
mm = [233.6,228.02, 232.25, 207.2]
ja = [207.2, 232.53, 214.79, 197.84]
sn = [197.84, 207.49, 184.65]
nd = [184.65, 161.98]
crimes= [238.64, 210.14, 233.66, 228.02, 232.25, 207.2, 232.53, 214.79, 197.84, 207.49, 184.65, 161.98]



plt.plot(x, jf,marker = "*", color = 'cornflowerblue')
plt.plot(y, mm, marker = "d", color = 'springgreen')
plt.plot(z, ja, marker = "o", color= 'red')
plt.plot(a, sn, marker = '^', color = 'peru')
plt.plot(d, nd, marker = '*', color = 'cornflowerblue')
plt.xlabel('Months')
plt.ylabel("Monthly Crime Rate \n (per 100,000)", fontsize = 9)
plt.xticks(rotation = '45')
plt.title("Crime Rate per Month")
plt.ylim([150,255])


plt.gcf().set_facecolor('white')
plt.gcf().set_size_inches(10,6)
plt.savefig('crime rate zoomed.png', bbox_inches="tight")
plt.show()
